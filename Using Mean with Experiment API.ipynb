# %%
from api import API
# Out:
# Using TensorFlow backend.
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\keras\backend.py:5201: ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\Hp\\.keras\\keras.json' mode='r' encoding='cp1252'>
#   _config = json.load(open(_config_path))

# %%
# REDD 

redd={
    'params': {
            'power': {'mains':['apparent'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge'],
    'methods': {
                    "Mean":{},"DAE":{'n_epochs':30,'appliance_params':{"fridge":{"mean":200,'std':100}}}
                },
    'chunk_size': None,
    'train': {    
    'datasets': {
            'REDD': {
                'path': 'C:/Users/Hp/Desktop/Rithwik/redd2.h5',
				'buildings': {
					2: {
						'start_time': '2011-04-21',
						'end_time': '2011-04-27'
					},                    
                }                
			}
		}
	},
	'test': {
		'datasets': {
			'REDD': {
                'path': 'C:/Users/Hp/Desktop/Rithwik/redd2.h5',
				'buildings': {
					2: {
						'start_time': '2011-04-27',
						'end_time': '2011-04-28'
					}
                }
			}
		},
        'metrics':['mae','rmse','rel_error']
	}
}

# %%
API(redd)
# Out:
# Started training for  Mean
# Joint training for  Mean
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Finished training for  Mean
# Started training for  DAE
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# First model training for  fridge
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\tensor_util.py:125: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   tensor_proto.float_val.extend([np.asscalar(x) for x in proto_values])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\tensor_util.py:131: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   tensor_proto.int_val.extend([np.asscalar(x) for x in proto_values])
# C:\Users\Hp\Anaconda3\envs\new_nilmtk\lib\site-packages\tensorflow\python\framework\tensor_util.py:134: DeprecationWarning: np.asscalar(a) is deprecated since NumPy v1.16, use a.item() instead
#   tensor_proto.int64_val.extend([np.asscalar(x) for x in proto_values])
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# =================================================================
# conv1d_3 (Conv1D)            (None, 99, 8)             40
# _________________________________________________________________
# flatten_2 (Flatten)          (None, 792)               0
# _________________________________________________________________
# dense_4 (Dense)              (None, 792)               628056
# _________________________________________________________________
# dense_5 (Dense)              (None, 128)               101504
# _________________________________________________________________
# dense_6 (Dense)              (None, 792)               102168
# _________________________________________________________________
# reshape_2 (Reshape)          (None, 99, 8)             0
# _________________________________________________________________
# conv1d_4 (Conv1D)            (None, 99, 1)             33
# =================================================================
# Total params: 831,801
# Trainable params: 831,801
# Non-trainable params: 0
# _________________________________________________________________
# None
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 4s 530us/step - loss: 1.1956 - val_loss: 0.7942
#
# Epoch 00001: val_loss improved from inf to 0.79422, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 335us/step - loss: 0.7495 - val_loss: 0.7031
#
# Epoch 00001: val_loss improved from inf to 0.70314, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 328us/step - loss: 0.6686 - val_loss: 0.5997
#
# Epoch 00001: val_loss improved from inf to 0.59966, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 314us/step - loss: 0.4891 - val_loss: 0.3978
#
# Epoch 00001: val_loss improved from inf to 0.39781, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 325us/step - loss: 0.3806 - val_loss: 0.3716
#
# Epoch 00001: val_loss improved from inf to 0.37157, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 319us/step - loss: 0.3585 - val_loss: 0.3532
#
# Epoch 00001: val_loss improved from inf to 0.35320, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 3s 357us/step - loss: 0.3470 - val_loss: 0.3416
#
# Epoch 00001: val_loss improved from inf to 0.34158, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 328us/step - loss: 0.3396 - val_loss: 0.3239
#
# Epoch 00001: val_loss improved from inf to 0.32390, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - ETA: 0s - loss: 0.330 - 2s 323us/step - loss: 0.3299 - val_loss: 0.3198
#
# Epoch 00001: val_loss improved from inf to 0.31975, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 332us/step - loss: 0.3203 - val_loss: 0.3157
#
# Epoch 00001: val_loss improved from inf to 0.31567, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 326us/step - loss: 0.3118 - val_loss: 0.3138
#
# Epoch 00001: val_loss improved from inf to 0.31382, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 325us/step - loss: 0.3042 - val_loss: 0.3022
#
# Epoch 00001: val_loss improved from inf to 0.30219, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 336us/step - loss: 0.2964 - val_loss: 0.2851
#
# Epoch 00001: val_loss improved from inf to 0.28509, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 324us/step - loss: 0.2884 - val_loss: 0.2841
#
# Epoch 00001: val_loss improved from inf to 0.28409, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 318us/step - loss: 0.2821 - val_loss: 0.2742
#
# Epoch 00001: val_loss improved from inf to 0.27419, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 326us/step - loss: 0.2732 - val_loss: 0.2809
#
# Epoch 00001: val_loss improved from inf to 0.28092, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 325us/step - loss: 0.2693 - val_loss: 0.2757
#
# Epoch 00001: val_loss improved from inf to 0.27567, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 328us/step - loss: 0.2621 - val_loss: 0.2691
#
# Epoch 00001: val_loss improved from inf to 0.26910, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 324us/step - loss: 0.2575 - val_loss: 0.2576
#
# Epoch 00001: val_loss improved from inf to 0.25758, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 318us/step - loss: 0.2522 - val_loss: 0.2624
#
# Epoch 00001: val_loss improved from inf to 0.26237, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 335us/step - loss: 0.2464 - val_loss: 0.2396
#
# Epoch 00001: val_loss improved from inf to 0.23965, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 339us/step - loss: 0.2392 - val_loss: 0.2392
#
# Epoch 00001: val_loss improved from inf to 0.23923, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 327us/step - loss: 0.2348 - val_loss: 0.2390
#
# Epoch 00001: val_loss improved from inf to 0.23896, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 331us/step - loss: 0.2291 - val_loss: 0.2353
#
# Epoch 00001: val_loss improved from inf to 0.23527, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 332us/step - loss: 0.2275 - val_loss: 0.2338
#
# Epoch 00001: val_loss improved from inf to 0.23382, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 325us/step - loss: 0.2259 - val_loss: 0.2089
#
# Epoch 00001: val_loss improved from inf to 0.20887, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 315us/step - loss: 0.2179 - val_loss: 0.2158
#
# Epoch 00001: val_loss improved from inf to 0.21579, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 327us/step - loss: 0.2127 - val_loss: 0.2103
#
# Epoch 00001: val_loss improved from inf to 0.21033, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 333us/step - loss: 0.2060 - val_loss: 0.2153
#
# Epoch 00001: val_loss improved from inf to 0.21526, saving model to temp-weights.h5
# Joint training for  DAE
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............DAE partial_fit running...............
# Doing Preprocessing
# Training processing
# Started Retraining model for  fridge
# Train on 7321 samples, validate on 1293 samples
# Epoch 1/1
# 7321/7321 [==============================] - 2s 324us/step - loss: 0.2048 - val_loss: 0.2018
#
# Epoch 00001: val_loss improved from inf to 0.20183, saving model to temp-weights.h5
# Finished training for  DAE
# Joint Testing for all algorithms
# Loading data for  REDD  dataset
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=9, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ............  mae  ..............
#              Mean        DAE
# fridge  79.353798  27.122982
# ............  rmse  ..............
#              Mean        DAE
# fridge  85.407753  47.338081
# ............  rel_error  ..............
#               Mean         DAE
# fridge  545.013952  133.804393

# %%
# REDD 

redd={
    'params': {
            'power': {'mains':['apparent'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['washing machine'],
    'methods': {
                    'FHMM_EXACT':{},"Mean":{}
                },
    'chunk_size': 30000,
    'train': {    
    'datasets': {
            'REDD': {
                'path': 'C:/Users/Hp/Desktop/Rithwik/redd2.h5',
				'buildings': {
					2: {
						'start_time': '2011-04-21',
						'end_time': '2011-04-27'
					},                    
                }                
			}
		}
	},
	'test': {
		'datasets': {
			'REDD': {
                'path': 'C:/Users/Hp/Desktop/Rithwik/redd2.h5',
				'buildings': {
					2: {
						'start_time': '2011-04-27',
						'end_time': '2011-04-28'
					}
                }
			}
		},
        'metrics':['mae','rmse','rel_error']
	}
}

# %%
API(redd)
# Out:
# Started training for  FHMM
# Joint training for  FHMM
# ............... Loading Data for training ...................
# Loading data for  REDD  dataset
# Loading building ...  2
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# .........................FHMM partial_fit.................
# (8640, 1)
# Training model for submeter 'washing machine'
# Learnt model for : washing machine
# washing machine
# print ........... GaussianHMM(algorithm='viterbi', covariance_type='full', covars_prior=0.01,
#             covars_weight=1, init_params='stmc', means_prior=0, means_weight=0,
#             min_covar=0.001, n_components=2, n_iter=10, params='stmc',
#             random_state=None, startprob_prior=1.0, tol=0.01,
#             transmat_prior=1.0, verbose=False)
# FHMM partial_fit end.................
# Finished training for  FHMM
# Started training for  Mean
# Chunk training for  Mean
# Loading data for  REDD  dataset
# Loading building ...  2
# MeterGroup(meters=
#   ElecMeter(instance=1, building=2, dataset='REDD', site_meter, appliances=[])
#   ElecMeter(instance=2, building=2, dataset='REDD', site_meter, appliances=[])
# )
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Starting enumeration..........
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# ...............Finished the Training Process ...................
# Finished training for  Mean
# Chunk Wise Testing for all algorithms
# ...............Started  the Testing Process ...................
# Loading data for  REDD  dataset
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=2, dataset='REDD')
# Done loading data all meters for this chunk.
# Dropping missing values
# Results for Dataset REDD Building 2 Chunk 0
# ............  mae  ..............
#                  FHMM_EXACT      Mean
# washing machine    0.169587  0.247113
# ............  rmse  ..............
#                  FHMM_EXACT      Mean
# washing machine    0.410425  0.448147
# ............  rel_error  ..............
#                  FHMM_EXACT      Mean
# washing machine    4.764616  7.195202
