# %%
from api import API
# Out:
# Using TensorFlow backend.
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# ...

# %%
redd = {
  'power': {
    'mains': ['apparent','active'],
    'appliance': ['apparent','active']
  },
  'chunk_size':600,
  'sample_rate': 60,
  'appliances': ['fridge','air conditioner','electric furnace','washing machine'],
  'methods': {
     'Mean': {},"FHMM_EXACT":{}#"FHMM_EXACT":{},"RNN":{},"Seq2Point":{},"Seq2Seq":{},"DAE":{},"WindowGRU":{},
      #'AFHMM_SAC':{},"AFHMM":{},"AFHMM":{},"DSC":{}
  },
   'train': {    
    'datasets': {
            'Dataport': {
                'path': 'dataport.hdf5',
				'buildings': {
				10: {
					'start_time': '2015-04-04',
					'end_time': '2015-04-24'
				},
# 				15: {
# 					'start_time': '2015-04-30',
# 					'end_time': '2015-05-20'
# 				},
# 				37: {
# 					'start_time': '2014-08-22',
# 					'end_time': '2014-09-12'
# 				}
				}
				                
			}
			}
	},
	'test': {
	'datasets': {
		'Datport': {
			'path': 'dataport.hdf5',
			'buildings': {
				10: {
					'start_time': '2015-04-25',
					'end_time': '2015-04-26'
					},
				15: {
					'start_time': '2015-05-20',
					'end_time': '2015-05-27'
					},
# 				37: {
# 					'start_time': '2014-08-22',
# 					'end_time': '2014-08-29'
# 					}
			}
	}
},
        'metrics':['mae','lae','rmse','relative_error']
}
}

# %%
res = API(redd)
# Out:
# Chunk Wise Testing for all algorithms
# ...............Started  the Testing Process ...................
# Loading data for  Datport  dataset
# Dropping missing values
# Results for Dataset Datport Building 10 Chunk 0
# ...
# ............  mae  ..............
#                         Mean  FHMM_EXACT
# fridge             53.027809   87.458473
# air conditioner   479.805634   30.549833
# electric furnace  151.227554  170.594681
# washing machine     2.490717  172.704315
# Loss function  lae  is not supported currently!
# ............  rmse  ..............
#                         Mean  FHMM_EXACT
# fridge             80.141498  112.936034
# air conditioner   616.593920   80.607753
# electric furnace  193.748851  228.045294
# washing machine     2.490717  249.692326
# ............  relative_error  ..............
#                       Mean  FHMM_EXACT
# fridge            1.630378   28.851339
# air conditioner   4.537114    1.049756
# electric furnace  4.336421  106.545288
# ...

# %%
res = API(redd)
# Out:
# Joint Testing for all algorithms
# Loading data for  Datport  dataset
# Dropping missing values
# ...
# ............  mae  ..............
#                         Mean
# fridge             47.008377
# air conditioner   412.801392
# electric furnace  127.573433
# washing machine     2.506111
