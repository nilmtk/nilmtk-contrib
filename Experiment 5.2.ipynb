# %%
from api import API
# Out:
# Using TensorFlow backend.
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:526: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint8 = np.dtype([("qint8", np.int8, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:527: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint8 = np.dtype([("quint8", np.uint8, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:528: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint16 = np.dtype([("qint16", np.int16, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:529: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_quint16 = np.dtype([("quint16", np.uint16, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:530: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   _np_qint32 = np.dtype([("qint32", np.int32, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\dtypes.py:535: FutureWarning: Passing (type, 1) or '1type' as a synonym of type is deprecated; in a future version of numpy, it will be understood as (type, (1,)) / '(1,)type'.
#   np_resource = np.dtype([("resource", np.ubyte, 1)])
# C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\keras\backend.py:5201: ResourceWarning: unclosed file <_io.TextIOWrapper name='C:\\Users\\Hp\\.keras\\keras.json' mode='r' encoding='cp1252'>
#   _config = json.load(open(_config_path))

# %%
redd = {
  'power': {
    'mains': ['apparent','active'],
    'appliance': ['apparent','active']
  },
  'sample_rate': 60,
  'appliances': ['fridge','air conditioner','electric furnace','washing machine'],
  'methods': {
     'Mean': {},"FHMM_EXACT":{},"RNN":{},"Seq2Point":{},"Seq2Seq":{},"DAE":{},"WindowGRU":{},'AFHMM_SAC':{},
      "AFHMM":{},"AFHMM":{},"DSC":{}
  },
   'train': {    
    'datasets': {
            'Dataport': {
                'path': 'dataport.hdf5',
				'buildings': {
				10: {
					'start_time': '2015-04-04',
					'end_time': '2015-04-24'
				},
				15: {
					'start_time': '2015-04-30',
					'end_time': '2015-05-20'
				},
				37: {
					'start_time': '2014-08-22',
					'end_time': '2014-09-12'
				}
				}
				                
			}
			}
	},
	'test': {
	'datasets': {
		'Datport': {
			'path': 'dataport.hdf5',
			'buildings': {
				10: {
					'start_time': '2015-04-24',
					'end_time': '2015-05-01'
					},
				15: {
					'start_time': '2015-05-20',
					'end_time': '2015-05-27'
					},
				37: {
					'start_time': '2014-08-22',
					'end_time': '2014-08-29'
					}
			}
	}
},
        'metrics':['mae']
}
}

# %%
api_res = API(redd)
# Out:
# Started training for  RNN
# <disaggregate.rnn.RNN object at 0x000001C76EEDBEF0> False None
# Joint training for  RNN
# ............... Loading Data for training ...................
# Loading data for  Dataport  dataset
# Loading building ...  10
# Dropping missing values
# Train Jointly
# (28800, 1) (28800, 1) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type']) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type'])
# Loading building ...  15
# Dropping missing values
# Train Jointly
# (28800, 1) (28800, 1) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type']) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type'])
# Loading building ...  37
# Dropping missing values
# Train Jointly
# (30240, 1) (30240, 1) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type']) MultiIndex([('power', 'active')],
#            names=['physical_quantity', 'type'])
# Training processing
# First model training for  fridge
# WARNING:tensorflow:From C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\framework\op_def_library.py:263: colocate_with (from tensorflow.python.framework.ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Colocations handled automatically by placer.
# WARNING:tensorflow:From C:\Users\Hp\Anaconda3\envs\nilmtk_env\lib\site-packages\tensorflow\python\ops\math_ops.py:3066: to_int32 (from tensorflow.python.ops.math_ops) is deprecated and will be removed in a future version.
# Instructions for updating:
# Use tf.cast instead.
# Train on 74664 samples, validate on 13176 samples
# Epoch 1/10
# 74664/74664 [==============================] - 43s 579us/step - loss: 9.8864e-04 - mean_squared_error: 9.8864e-04 - val_loss: 8.6375e-04 - val_mean_squared_error: 8.6375e-04
#
# Epoch 00001: val_loss improved from inf to 0.00086, saving model to temp-weights.h5
# Epoch 2/10
# 74664/74664 [==============================] - 41s 543us/step - loss: 8.0805e-04 - mean_squared_error: 8.0805e-04 - val_loss: 7.9174e-04 - val_mean_squared_error: 7.9174e-04
#
# Epoch 00002: val_loss improved from 0.00086 to 0.00079, saving model to temp-weights.h5
# Epoch 3/10
# 74664/74664 [==============================] - 41s 543us/step - loss: 7.8969e-04 - mean_squared_error: 7.8969e-04 - val_loss: 8.5418e-04 - val_mean_squared_error: 8.5418e-04
#
# Epoch 00003: val_loss did not improve from 0.00079
# Epoch 4/10
# 74664/74664 [==============================] - 45s 605us/step - loss: 7.8904e-04 - mean_squared_error: 7.8904e-04 - val_loss: 8.1542e-04 - val_mean_squared_error: 8.1542e-04
#
# Epoch 00004: val_loss did not improve from 0.00079
# Epoch 5/10
# 74664/74664 [==============================] - 44s 594us/step - loss: 7.8548e-04 - mean_squared_error: 7.8548e-04 - val_loss: 7.9125e-04 - val_mean_squared_error: 7.9125e-04
#
# Epoch 00005: val_loss improved from 0.00079 to 0.00079, saving model to temp-weights.h5
# Epoch 6/10
# 74664/74664 [==============================] - 45s 603us/step - loss: 7.8324e-04 - mean_squared_error: 7.8324e-04 - val_loss: 7.7986e-04 - val_mean_squared_error: 7.7986e-04
#
# Epoch 00006: val_loss improved from 0.00079 to 0.00078, saving model to temp-weights.h5
# Epoch 7/10
# 74664/74664 [==============================] - 45s 602us/step - loss: 7.8085e-04 - mean_squared_error: 7.8085e-04 - val_loss: 7.8857e-04 - val_mean_squared_error: 7.8857e-04
#
# Epoch 00007: val_loss did not improve from 0.00078
# Epoch 8/10
# 74664/74664 [==============================] - 44s 595us/step - loss: 7.8000e-04 - mean_squared_error: 7.8000e-04 - val_loss: 7.9758e-04 - val_mean_squared_error: 7.9758e-04
#
# Epoch 00008: val_loss did not improve from 0.00078
# Epoch 9/10
# 74664/74664 [==============================] - 44s 587us/step - loss: 7.7935e-04 - mean_squared_error: 7.7935e-04 - val_loss: 7.8224e-04 - val_mean_squared_error: 7.8224e-04
#
# Epoch 00009: val_loss did not improve from 0.00078
# Epoch 10/10
# 74664/74664 [==============================] - 43s 579us/step - loss: 7.7895e-04 - mean_squared_error: 7.7895e-04 - val_loss: 7.7799e-04 - val_mean_squared_error: 7.7799e-04
#
# Epoch 00010: val_loss improved from 0.00078 to 0.00078, saving model to temp-weights.h5
# First model training for  air conditioner
# Train on 74664 samples, validate on 13176 samples
# Epoch 1/10
# 74664/74664 [==============================] - 50s 663us/step - loss: 0.0184 - mean_squared_error: 0.0184 - val_loss: 0.0168 - val_mean_squared_error: 0.0168
#
# Epoch 00001: val_loss improved from inf to 0.01684, saving model to temp-weights.h5
# Epoch 2/10
# 74664/74664 [==============================] - 43s 571us/step - loss: 0.0152 - mean_squared_error: 0.0152 - val_loss: 0.0119 - val_mean_squared_error: 0.0119
#
# Epoch 00002: val_loss improved from 0.01684 to 0.01190, saving model to temp-weights.h5
# Epoch 3/10
# 74664/74664 [==============================] - 41s 543us/step - loss: 0.0110 - mean_squared_error: 0.0110 - val_loss: 0.0126 - val_mean_squared_error: 0.0126
#
# Epoch 00003: val_loss did not improve from 0.01190
# Epoch 4/10
# 64128/74664 [========================>.....] - ETA: 5s - loss: 0.0107 - mean_squared_error: 0.0107
