# %%
from api import API
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Using TensorFlow backend.
# /data/anaconda/envs/n3/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:5201: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/nilmtk1/.keras/keras.json' mode='r' encoding='UTF-8'>
#   _config = json.load(open(_config_path))

# %%
# Dataport DAE

dataport={
    'params': {
            'power': {'mains':['active'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge','air conditioner','washing machine','microwave'],
    'methods': {'CO':{},'FHMM':{}
               },
    'pre_trained': False,
    'preprocessing': False,
    'chunk_size': 100000,
   
    'train': {    
    'datasets': {
            'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    54: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    56: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    57: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    62: {
'start_time': '2014-09-06',
'end_time': '2014-09-20'
},
                    63: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    64: {
'start_time': '2015-04-14',
'end_time': '2015-04-28'
},
                    65: {
'start_time': '2014-09-23',
'end_time': '2014-10-07'
},
                    69: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    71: {
'start_time': '2014-12-25',
'end_time': '2015-01-09'
},
                    72: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
}
                            }
               
}
}
},
'test': {
'datasets': {
'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    94: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    103: {
'start_time': '2014-01-26',
'end_time': '2014-02-03'
},
                    113: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    117: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    122: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
}
                }
}
},
        'metrics':['rmse']
}
}

# %%
obj = API(dataport)
# Out:
# oo Chunk Training
# ...
# ............... Loading Data for preprocessing ...................
# ............... Loading Train_Mains for preprocessing ...................
# Loading data for  Dataport  dataset
# Loading building ...  54
# ['fridge', 'air conditioner', 'washing machine', 'microwave']
# ElecMeter(instance=1, building=54, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=10, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=8, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# ...

# %%
# Dataport DAE

d2={
    'params': {
            'power': {'mains':['active'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge','air conditioner','washing machine','microwave'],
    'methods': {'Seq2Seq' :{'n_epochs':1, 'batch_size':4096, 'sequence-length':39,
                    'appliance_params': {
                                'washing machine':{
                                    'mean': 400,
                                    'std': 700
                                },
                               'fridge':{
                                    'mean': 200,
                                    'std': 400
                                },
                                'air conditioner':{
                                    'mean': 1000,
                                    'std': 6000
                                },
                                'microwave':{
                                    'mean': 500,
                                    'std': 800
                                }
                        },
                   },
               },
    'pre_trained': False,
    'preprocessing': False,
    'chunk_size': 100000,
   
    'train': {    
    'datasets': {
            'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    54: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    56: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    57: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    62: {
'start_time': '2014-09-06',
'end_time': '2014-09-20'
},
                    63: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    64: {
'start_time': '2015-04-14',
'end_time': '2015-04-28'
},
                    65: {
'start_time': '2014-09-23',
'end_time': '2014-10-07'
},
                    69: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    71: {
'start_time': '2014-12-25',
'end_time': '2015-01-09'
},
                    72: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
}
                            }
               
}
}
},
'test': {
'datasets': {
'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    94: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    103: {
'start_time': '2014-01-26',
'end_time': '2014-02-03'
},
                    113: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    117: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    122: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
}
                }
}
},
        'metrics':['rmse']
}
}

# %%
o = API(d2)
# Out:
# oo Chunk Training
# ...
# ............... Loading Data for preprocessing ...................
# ............... Loading Train_Mains for preprocessing ...................
# Loading data for  Dataport  dataset
# Loading building ...  54
# ['fridge', 'air conditioner', 'washing machine', 'microwave']
# ElecMeter(instance=1, building=54, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=10, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=8, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# Loading building ...  56
# ...

# %%
# Dataport DAE

d4={
    'params': {
            'power': {'mains':['active'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge','air conditioner','washing machine','microwave'],
    'methods': {'DAE' :{'n_epochs':100, 'batch_size':4096, 'sequence-length':199,
                    'appliance_params': {
                                'washing machine':{
                                    'mean': 800,
                                    'std': 1200
                                },
                               'fridge':{
                                    'mean': 200,
                                    'std': 400
                                },
                                'air conditioner':{
                                    'mean': 1000,
                                    'std': 6000
                                },
                                'microwave':{
                                    'mean': 600,
                                    'std': 2000
                                }
                        },
                   },
               },
    'pre_trained': False,
    'preprocessing': False,
    'chunk_size': 100000,
   
    'train': {    
    'datasets': {
            'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    54: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    56: {
'start_time': '2015-01-28',
'end_time': '2015-02-12'
},
                    57: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    62: {
'start_time': '2014-09-06',
'end_time': '2014-09-20'
},
                    63: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    64: {
'start_time': '2015-04-14',
'end_time': '2015-04-28'
},
                    65: {
'start_time': '2014-09-23',
'end_time': '2014-10-07'
},
                    69: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
},
                    71: {
'start_time': '2014-12-25',
'end_time': '2015-01-09'
},
                    72: {
'start_time': '2015-04-30',
'end_time': '2015-05-14'
}
                            }
               
}
}
},
'test': {
'datasets': {
'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    94: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    103: {
'start_time': '2014-01-26',
'end_time': '2014-02-03'
},
                    113: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    117: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
},
                    122: {
'start_time': '2015-04-30',
'end_time': '2015-05-07'
}
                }
}
},
        'metrics':['rmse']
}
}

# %%
o = API(d4)
# Out:
# oo Chunk Training
# ...
# ............... Loading Data for preprocessing ...................
# ............... Loading Train_Mains for preprocessing ...................
# Loading data for  Dataport  dataset
# Loading building ...  54
# ['fridge', 'air conditioner', 'washing machine', 'microwave']
# ElecMeter(instance=1, building=54, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=10, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=8, building=54, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# ...
