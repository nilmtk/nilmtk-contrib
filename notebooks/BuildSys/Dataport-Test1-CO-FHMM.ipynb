# %%
from api import API
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "1"
# Out:
# Using TensorFlow backend.
# /data/anaconda/envs/n3/lib/python3.6/site-packages/tensorflow/python/keras/backend.py:5201: ResourceWarning: unclosed file <_io.TextIOWrapper name='/home/nilmtk1/.keras/keras.json' mode='r' encoding='UTF-8'>
#   _config = json.load(open(_config_path))

# %%
# Dataport actual
d={
    'params': {
            'power': {'mains':['active'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge','air conditioner','electric furnace','washing machine'],
    'methods': {
                'CO':{}
                
               
               },
    'pre_trained': False,
    'preprocessing': False,
    'chunk_size': 100000,
   
    'train': {    
    'datasets': {
            'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    10: {
'start_time': '2015-04-04',
'end_time': '2015-04-24'
},
                    15: {
'start_time': '2015-04-30',
'end_time': '2015-05-20'
},
                    37: {
'start_time': '2014-08-22',
'end_time': '2014-09-12'
}
                }
               
}
}
},
'test': {
'datasets': {
'Datport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    10: {
'start_time': '2015-04-24',
'end_time': '2015-05-01'
},
                    15: {
'start_time': '2015-05-20',
'end_time': '2015-05-27'
},
                    37: {
'start_time': '2014-08-22',
'end_time': '2014-08-29'
}
                }
}
},
        'metrics':['rmse']
}
}

# %%
obj = API(d)
# Out:
# oo Chunk Training
# <api.API object at 0x7f4ab02a7ef0>
# ............... Loading Data for preprocessing ...................
# ............... Loading Train_Mains for preprocessing ...................
# Loading data for  Dataport  dataset
# Loading building ...  10
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=10, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=10, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# CO <disaggregate.combinatorial_optimisation.CombinatorialOptimisation object at 0x7f4ab02a7240>
# ...............CO partial_fit running.............
# Loading building ...  15
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=15, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=8, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# CO <disaggregate.combinatorial_optimisation.CombinatorialOptimisation object at 0x7f4ab02a7240>
# ...............CO partial_fit running.............
# Trained on fridge before.
# Trained on air conditioner before.
# Trained on electric furnace before.
# Trained on washing machine before.
# Loading building ...  37
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=37, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=11, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# CO <disaggregate.combinatorial_optimisation.CombinatorialOptimisation object at 0x7f4ab02a7240>
# ...............CO partial_fit running.............
# Trained on fridge before.
# Trained on air conditioner before.
# Trained on electric furnace before.
# Trained on washing machine before.
# ...............Finished Loading Train mains and Appliances for preprocessing ...................
# Loading data for  Datport  dataset
# Loading data for meter ElecMeterID(instance=10, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 10 chunk 0
# ...............CO disaggregate_chunk running.............
# Estimating power demand for 'fridge'
# Estimating power demand for 'air conditioner'
# Estimating power demand for 'electric furnace'
# Estimating power demand for 'washing machine'
# ............  rmse  ..............
#                      CO
# fridge            152.1
# air conditioner   260.7
# electric furnace  151.2
# washing machine   199.1
# Loading data for meter ElecMeterID(instance=8, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 15 chunk 0
# ...............CO disaggregate_chunk running.............
# Estimating power demand for 'fridge'
# Estimating power demand for 'air conditioner'
# Estimating power demand for 'electric furnace'
# Estimating power demand for 'washing machine'
# ............  rmse  ..............
#                      CO
# fridge            165.3
# air conditioner   254.1
# electric furnace  166.5
# washing machine   221.5
# Loading data for meter ElecMeterID(instance=11, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 37 chunk 0
# ...............CO disaggregate_chunk running.............
# Estimating power demand for 'fridge'
# Estimating power demand for 'air conditioner'
# Estimating power demand for 'electric furnace'
# Estimating power demand for 'washing machine'
# ............  rmse  ..............
#                      CO
# fridge            171.2
# air conditioner   216.2
# electric furnace  144.4
# washing machine   264.7

# %%
# Dataport actual
d2={
    'params': {
            'power': {'mains':['active'],
                      'appliance':['active']
                     }
        },
    'sample_rate': 60,
    'appliances': ['fridge','air conditioner','electric furnace','washing machine'],
    'methods': {
                'FHMM':{}
                
               
               },
    'pre_trained': False,
    'preprocessing': False,
    'chunk_size': 100000,
   
    'train': {    
    'datasets': {
            'Dataport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    10: {
'start_time': '2015-04-04',
'end_time': '2015-04-24'
},
                    15: {
'start_time': '2015-04-30',
'end_time': '2015-05-20'
},
                    37: {
'start_time': '2014-08-22',
'end_time': '2014-09-12'
}
                }
               
}
}
},
'test': {
'datasets': {
'Datport': {
                'path': '/home/nilmtk1/ayush/data/dataport2.h5',
'buildings': {
                    10: {
'start_time': '2015-04-24',
'end_time': '2015-05-01'
},
                    15: {
'start_time': '2015-05-20',
'end_time': '2015-05-27'
},
                    37: {
'start_time': '2014-08-22',
'end_time': '2014-08-29'
}
                }
}
},
        'metrics':['rmse']
}
}

# %%
o = API(d2)
# Out:
# oo Chunk Training
# <api.API object at 0x7f4ab00c1710>
# ............... Loading Data for preprocessing ...................
# ............... Loading Train_Mains for preprocessing ...................
# Loading data for  Dataport  dataset
# Loading building ...  10
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=10, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=10, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# FHMM <disaggregate.fhmm_exact.FHMM object at 0x7f4ab00c1208>
# .........................FHMM partial_fit.................
# Training model for submeter 'fridge'
# Learnt model for : fridge
# Training model for submeter 'air conditioner'
# Learnt model for : air conditioner
# Training model for submeter 'electric furnace'
# Learnt model for : electric furnace
# Training model for submeter 'washing machine'
# Learnt model for : washing machine
# FHMM partial_fit end.................
# Loading building ...  15
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=15, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=8, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# FHMM <disaggregate.fhmm_exact.FHMM object at 0x7f4ab00c1208>
# .........................FHMM partial_fit.................
# Training model for submeter 'fridge'
# Learnt model for : fridge
# Training model for submeter 'air conditioner'
# Learnt model for : air conditioner
# Training model for submeter 'electric furnace'
# Learnt model for : electric furnace
# Training model for submeter 'washing machine'
# Learnt model for : washing machine
# FHMM partial_fit end.................
# Loading building ...  37
# ['fridge', 'air conditioner', 'electric furnace', 'washing machine']
# ElecMeter(instance=1, building=37, dataset='Dataport', site_meter, appliances=[])
# starting enumeration..........
# Loading data for meter ElecMeterID(instance=11, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Called Partial fit
# FHMM <disaggregate.fhmm_exact.FHMM object at 0x7f4ab00c1208>
# .........................FHMM partial_fit.................
# Training model for submeter 'fridge'
# Learnt model for : fridge
# Training model for submeter 'air conditioner'
# Learnt model for : air conditioner
# Training model for submeter 'electric furnace'
# Learnt model for : electric furnace
# Training model for submeter 'washing machine'
# Learnt model for : washing machine
# FHMM partial_fit end.................
# ...............Finished Loading Train mains and Appliances for preprocessing ...................
# Loading data for  Datport  dataset
# Loading data for meter ElecMeterID(instance=10, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=10, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 10 chunk 0
# ............  rmse  ..............
#                    FHMM
# fridge            101.9
# air conditioner   267.6
# electric furnace  117.0
# washing machine   105.7
# Loading data for meter ElecMeterID(instance=8, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=6, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=15, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 15 chunk 0
# ............  rmse  ..............
#                    FHMM
# fridge             91.5
# air conditioner   268.6
# electric furnace  191.9
# washing machine   142.5
# Loading data for meter ElecMeterID(instance=11, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=2, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=7, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Loading data for meter ElecMeterID(instance=3, building=37, dataset='Dataport')
# Done loading data all meters for this chunk.
# Droppping NANS
# Dataset Datport Building 37 chunk 0
# ............  rmse  ..............
#                    FHMM
# fridge            111.7
# air conditioner   232.0
# electric furnace  138.1
# washing machine   130.0
